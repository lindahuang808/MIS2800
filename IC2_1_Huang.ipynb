# %% [markdown]
# <a href="https://colab.research.google.com/github/lindahuang808/MIS2800/blob/main/IC2_1_Huang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("SQL Environment Ready")
# Out:
# SQL Environment Ready
